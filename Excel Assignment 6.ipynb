# %% [raw]
# ## Sumifs , sumproducts and pivot table
# formula :=SUMIFS($C$2:$C$150000,$B$2:$B$150000,$E16,$A$2:$A$150000,G$15)
#
# for sumproduct:
#
# formula:=SUMPRODUCT(($C$2:$C$150000)*($B$2:$B$150000=$E3)*($A$2:$A$150000=F$2))

# %% [markdown]
# ## Below are the result

# %% [markdown]
# ![Screenshot%20%2815%29.png](attachment:Screenshot%20%2815%29.png)

# %% [markdown]
# ![Screenshot%20%2816%29.png](attachment:Screenshot%20%2816%29.png)
