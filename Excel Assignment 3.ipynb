# %% [markdown]
# In another column, use this formula to extract the common terms;
#
# =LEFT(SUBSTITUTE(IF(ISNUMBER(FIND("(",A2)),SUBSTITUTE(A2,"("," "),SUBSTITUTE(A2&"-","-","%"))," ","%",2),FIND("%",SUBSTITUTE(IF(ISNUMBER(FIND("(",A2)),SUBSTITUTE(A2,"("," "),SUBSTITUTE(A2&"-","-","%"))," ","%",2))-1)
#
#
# Then Add this formula in the count column:
#
# =IF(COUNTIF($E$1:E2,E2)=1,COUNTIF(E:E,E2),"")
#
# Below is showing the formula using sow formula option
# ![Screen%20Shot%202022-01-07%20at%208.16.50%20AM.png](attachment:Screen%20Shot%202022-01-07%20at%208.16.50%20AM.png)

# %% [markdown]
# ## Below is the result
#
# ![Screen%20Shot%202022-01-07%20at%208.18.37%20AM.png](attachment:Screen%20Shot%202022-01-07%20at%208.18.37%20AM.png)
