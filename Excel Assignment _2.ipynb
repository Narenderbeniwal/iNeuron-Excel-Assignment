# %% [markdown]
# I have applied various formulas such as  countif, countifs,sumif and sumifs functions.
#
# In order to show all the applied formulas, I have enabled "Show Formulas" option under Formulas:
#     ![Screen%20Shot%202022-01-06%20at%206.47.35%20PM.png](attachment:Screen%20Shot%202022-01-06%20at%206.47.35%20PM.png)

# %% [markdown]
# Below are the answers:
#
#
#
# ![Screen%20Shot%202022-01-06%20at%206.47.53%20PM.png](attachment:Screen%20Shot%202022-01-06%20at%206.47.53%20PM.png)

# %% [markdown]
# ## Similarly, I have applied below formulas to complete Task 2

# %% [markdown]
# ![Screen%20Shot%202022-01-06%20at%206.49.40%20PM.png](attachment:Screen%20Shot%202022-01-06%20at%206.49.40%20PM.png)

# %% [markdown]
# Result for task 2
#
# ![Screen%20Shot%202022-01-06%20at%206.50.21%20PM.png](attachment:Screen%20Shot%202022-01-06%20at%206.50.21%20PM.png)
